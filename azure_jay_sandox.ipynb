# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in /Users/jaysampat/Library/Python/3.9/lib/python/site-packages (2.2.3)
# Requirement already satisfied: pytz>=2020.1 in /Users/jaysampat/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/jaysampat/Library/Python/3.9/lib/python/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/jaysampat/Library/Python/3.9/lib/python/site-packages (from pandas) (2024.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/jaysampat/Library/Python/3.9/lib/python/site-packages (from pandas) (2.0.2)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.15.0)
# WARNING: You are using pip version 21.2.4; however, version 24.2 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
errors = pd.read_csv('archive/PdM_errors.csv')
errors
# Out:
#                  datetime  machineID errorID
# 0     2015-01-03 07:00:00          1  error1
# 1     2015-01-03 20:00:00          1  error3
# 2     2015-01-04 06:00:00          1  error5
# 3     2015-01-10 15:00:00          1  error4
# 4     2015-01-22 10:00:00          1  error4
# ...                   ...        ...     ...
# 3914  2015-11-21 08:00:00        100  error2
# 3915  2015-12-04 02:00:00        100  error1
# 3916  2015-12-08 06:00:00        100  error2
# 3917  2015-12-08 06:00:00        100  error3
# 3918  2015-12-22 03:00:00        100  error3
#
# [3919 rows x 3 columns]

# %%
failures = pd.read_csv('archive/PdM_failures.csv')
failures
# Out:
#                 datetime  machineID failure
# 0    2015-01-05 06:00:00          1   comp4
# 1    2015-03-06 06:00:00          1   comp1
# 2    2015-04-20 06:00:00          1   comp2
# 3    2015-06-19 06:00:00          1   comp4
# 4    2015-09-02 06:00:00          1   comp4
# ..                   ...        ...     ...
# 756  2015-11-29 06:00:00         99   comp3
# 757  2015-12-14 06:00:00         99   comp4
# 758  2015-02-12 06:00:00        100   comp1
# 759  2015-09-10 06:00:00        100   comp1
# 760  2015-12-09 06:00:00        100   comp2
#
# [761 rows x 3 columns]

# %%
machines = pd.read_csv('archive/PdM_machines.csv')
machines
# Out:
#     machineID   model  age
# 0           1  model3   18
# 1           2  model4    7
# 2           3  model3    8
# 3           4  model3    7
# 4           5  model3    2
# ..        ...     ...  ...
# 95         96  model2   10
# 96         97  model2   14
# 97         98  model2   20
# 98         99  model1   14
# 99        100  model4    5
#
# [100 rows x 3 columns]

# %%
maint = pd.read_csv('archive/PdM_maint.csv')
maint
# Out:
#                  datetime  machineID   comp
# 0     2014-06-01 06:00:00          1  comp2
# 1     2014-07-16 06:00:00          1  comp4
# 2     2014-07-31 06:00:00          1  comp3
# 3     2014-12-13 06:00:00          1  comp1
# 4     2015-01-05 06:00:00          1  comp4
# ...                   ...        ...    ...
# 3281  2015-10-10 06:00:00        100  comp3
# 3282  2015-10-25 06:00:00        100  comp4
# 3283  2015-11-09 06:00:00        100  comp4
# 3284  2015-12-09 06:00:00        100  comp2
# 3285  2015-12-24 06:00:00        100  comp2
#
# [3286 rows x 3 columns]

# %%
telemetry = pd.read_csv('archive/PdM_telemetry.csv')
telemetry
# Out:
#                    datetime  machineID        volt      rotate    pressure  \
# 0       2015-01-01 06:00:00          1  176.217853  418.504078  113.077935
# 1       2015-01-01 07:00:00          1  162.879223  402.747490   95.460525
# 2       2015-01-01 08:00:00          1  170.989902  527.349825   75.237905
# 3       2015-01-01 09:00:00          1  162.462833  346.149335  109.248561
# 4       2015-01-01 10:00:00          1  157.610021  435.376873  111.886648
# ...                     ...        ...         ...         ...         ...
# 876095  2016-01-01 02:00:00        100  179.438162  395.222827  102.290715
# 876096  2016-01-01 03:00:00        100  189.617555  446.207972   98.180607
# 876097  2016-01-01 04:00:00        100  192.483414  447.816524   94.132837
# 876098  2016-01-01 05:00:00        100  165.475310  413.771670  104.081073
# 876099  2016-01-01 06:00:00        100  171.336037  496.096870   79.095538
#
#         vibration
# 0       45.087686
# 1       43.413973
# 2       34.178847
# 3       41.122144
# 4       25.990511
# ...           ...
# 876095  50.771941
# 876096  35.123072
# 876097  48.314561
# 876098  44.835259
# 876099  37.845245
#
# [876100 rows x 6 columns]
